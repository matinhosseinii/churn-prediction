# %%
import kaggle
file_path = "..\\..\\data\\01_Raw"
kaggle.api.dataset_download_files(
                    dataset="shrutimechlearn/churn-modelling",
                    path=file_path,
                    unzip=True
                )
print(f'the raw dataset has been downloaded and saved in this path: {file_path}')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shrutimechlearn/churn-modelling
# the raw dataset has been downloaded and saved in this path: ..\..\data\01_Raw

# %%
import pandas as pd

raw_dataset = pd.read_csv(f"{file_path}\\Churn_Modelling.csv")
raw_dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
raw_dataset.drop_duplicates(inplace=True)
raw_dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(raw_dataset, random_state=42, test_size=0.2)

# %%
train
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9254       9255    15601116         P'an          686    France    Male   32
# 1561       1562    15766374         Leak          632   Germany    Male   42
# 1670       1671    15716994        Green          559     Spain    Male   24
# 6087       6088    15730759     Chukwudi          561    France  Female   27
# 6669       6670    15797900     Chinomso          517    France    Male   56
# ...         ...         ...          ...          ...       ...     ...  ...
# 5734       5735    15596647    Henderson          768    France    Male   54
# 5191       5192    15681075  Chukwualuka          682    France  Female   58
# 5390       5391    15573851    Macrossan          735    France  Female   38
# 860         861    15807663     McGregor          667    France    Male   43
# 7270       7271    15706268        Smith          697   Germany    Male   51
#
# ...

# %%
test
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 6252       6253    15687492  Anderson          596   Germany    Male   32
# 4684       4685    15736963   Herring          623    France    Male   43
# 1731       1732    15721730    Amechi          601     Spain  Female   44
# 4742       4743    15762134     Liang          506   Germany    Male   59
# 4521       4522    15648898    Chuang          560     Spain  Female   27
# ...         ...         ...       ...          ...       ...     ...  ...
# 6412       6413    15598982     Klein          602   Germany  Female   53
# 8285       8286    15572631  Ndubuisi          609    France    Male   25
# 7853       7854    15746674    Miller          730    France  Female   47
# 1095       1096    15689081        Wu          692    France    Male   29
# 6929       6930    15651627     White          628   Germany    Male   39
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...
